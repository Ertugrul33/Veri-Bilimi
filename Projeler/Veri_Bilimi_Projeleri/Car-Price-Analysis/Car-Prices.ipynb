# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_csv("CarPrice_Assignment.csv")

# %%
dataFrame
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
for i in dataFrame:
    if dataFrame.dtypes[i] == object:
        dataFrame = dataFrame.drop(i, axis = 1)
        
#String olan tüm satırlar silindi.

# %%
dataFrame.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
dataFrame.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
dataFrame = dataFrame.drop(["car_ID","symboling"], axis = 1)

# %%
dataFrame
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
dataFrame.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize   boreratio      stroke  compressionratio  horsepower  \
# count  205.000000  205.000000  205.000000        205.000000  205.000000
# mean   126.907317    3.329756    3.255415         10.142537  104.117073
# std     41.642693    0.270844    0.313597          3.972040   39.544167
# min     61.000000    2.540000    2.070000          7.000000   48.000000
# ...

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# highwaympg         -0.697599
# citympg            -0.685751
# peakrpm            -0.085267
# compressionratio    0.067984
# stroke              0.079443
# carheight           0.119336
# boreratio           0.553173
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# horsepower          0.808139
# curbweight          0.835305
# enginesize          0.874145
# price               1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])

# %%
dataFrame.sort_values("price", ascending = True).head(100)
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 138       93.7      156.9      63.4       53.7        2050          97
# 18        88.4      141.1      60.3       53.2        1488          61
# 50        93.1      159.1      64.2       54.1        1890          91
# 150       95.7      158.7      63.6       54.5        1985          92
# 76        93.7      157.3      64.4       50.8        1918          92
# ..         ...        ...       ...        ...         ...         ...
# 143       97.2      172.0      65.4       52.5        2340         108
# 190       94.5      165.7      64.0       51.4        2221         109
# 175      102.4      175.6      66.5       53.9        2414         122
# 169       98.4      176.2      65.6       52.0        2551         146
# 188       97.3      171.7      65.5       55.7        2300         109
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
plt.hist(dataFrame["price"])
# Out:
# (array([83., 45., 35., 18.,  6.,  3.,  5.,  7.,  2.,  1.]),
#  array([ 5118. ,  9146.2, 13174.4, 17202.6, 21230.8, 25259. , 29287.2,
#         33315.4, 37343.6, 41371.8, 45400. ]),
#  <a list of 10 Patch objects>)

# %%
from scipy.stats import kstest

# %%
statistic, pvalue = kstest(dataFrame['price'], 'norm')
print('statistic=%.3f, p=%.3f\n' % (statistic, pvalue))

if pvalue > 0.05:
    print("Normaldir.")
else:
    print("Normal Değildir.")
# Out:
# statistic=1.000, p=0.000
#
# Normal Değildir.

# %%
print (stats.shapiro(np.log(dataFrame['price'])))
# Out:
# ShapiroResult(statistic=0.9486748576164246, pvalue=1.0736105195974233e-06)

# %%
np.log(dataFrame["price"])
# Out:
# 0       9.510075
# 1       9.711116
# 2       9.711116
# 3       9.543235
# 4       9.767095
#          ...
# 200     9.731809
# 201     9.854560
# 202     9.975110
# 203    10.019936
# 204    10.026811
# Name: price, Length: 205, dtype: float64

# %%
plt.hist(np.log(dataFrame["price"]))
# Out:
# (array([15., 41., 37., 28., 21., 35.,  8.,  5., 10.,  5.]),
#  array([ 8.54051902,  8.75879385,  8.97706869,  9.19534353,  9.41361836,
#          9.6318932 ,  9.85016804, 10.06844287, 10.28671771, 10.50499255,
#         10.72326738]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(7,5))
sbn.distplot(np.log(dataFrame["price"]))

# %%
statistic, pvalue = kstest(np.log(dataFrame['price']), 'norm')
print('statistic=%.3f, p=%.3f\n' % (statistic, pvalue))

if pvalue > 0.05:
    print("Normaldir.")
else:
    print("Normal Değildir.")
# Out:
# statistic=1.000, p=0.000
#
# Normal Değildir.

# %%
len(dataFrame)
# Out:
# 205

# %%
len(dataFrame) * 0.01
# Out:
# 2.05

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price", ascending = False).iloc[2:]

# %%
yuzdeDoksanDokuzDf.sort_values("price", ascending = False)
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 73       120.9      208.1      71.7       56.7        3900         308
# 128       89.5      168.9      65.0       51.6        2800         194
# 17       110.0      197.0      70.9       56.3        3505         209
# 49       102.0      191.7      70.6       47.8        3950         326
# 48       113.0      199.6      69.6       52.8        4066         258
# ..         ...        ...       ...        ...         ...         ...
# 76        93.7      157.3      64.4       50.8        1918          92
# 150       95.7      158.7      63.6       54.5        1985          92
# 50        93.1      159.1      64.2       54.1        1890          91
# 18        88.4      141.1      60.3       53.2        1488          61
# 138       93.7      156.9      63.4       53.7        2050          97
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
plt.figure(figsize=(7,5))
sbn.distplot((yuzdeDoksanDokuzDf["price"]))

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#         wheelbase   carlength   carwidth   carheight   curbweight  enginesize  \
# count  203.000000  203.000000  203.00000  203.000000   203.000000  203.000000
# mean    98.667980  173.828079   65.86798   53.716749  2545.793103  125.630542
# std      5.969361   12.190320    2.10772    2.452745   513.494335   39.509824
# min     86.600000  141.100000   60.30000   47.800000  1488.000000   61.000000
# 25%     94.500000  166.300000   64.05000   52.000000  2145.000000   97.000000
# 50%     96.900000  173.200000   65.50000   54.100000  2414.000000  119.000000
# 75%    101.600000  181.600000   66.55000   55.500000  2923.500000  141.000000
# max    120.900000  208.100000   72.30000   59.800000  4066.000000  326.000000
#
#         boreratio      stroke  compressionratio  horsepower      peakrpm  \
# count  203.000000  203.000000        203.000000  203.000000   203.000000
# mean     3.326010    3.254286         10.163645  103.339901  5126.847291
# ...

# %%
plt.figure(figsize=(7,5))
sbn.distplot((np.log(yuzdeDoksanDokuzDf["price"])))

# %%
statistic, pvalue = kstest(np.log(yuzdeDoksanDokuzDf['price']), 'norm')
print('statistic=%.3f, p=%.3f\n' % (statistic, pvalue))

if pvalue > 0.05:
    print("Normaldir.")
else:
    print("Normal Değildir.")
# Out:
# statistic=1.000, p=0.000
#
# Normal Değildir.
