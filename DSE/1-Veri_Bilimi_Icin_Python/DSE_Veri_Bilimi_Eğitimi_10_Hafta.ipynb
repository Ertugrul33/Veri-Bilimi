# %% [markdown]
# # Python İle Veri Görselleştirme
#
#
#
# 1.   Matplotlib
# 2.   Pandas
# 3.   Seaborn
# 4.   ggplot

# %% [markdown]
# **Veriye İlk Bakış**

# %%
import seaborn as sns

# %%
# ?sns.load_dataset()

# %%
df_planets = sns.load_dataset("planets")

# %%
type(df_planets)
# Out:
# pandas.core.frame.DataFrame

# %%
df_planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df_planets.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df_planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df_planets.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
import pandas as pd

# %%
df_planets["method"]
# Out:
# 0       Radial Velocity
# 1       Radial Velocity
# 2       Radial Velocity
# 3       Radial Velocity
# 4       Radial Velocity
#              ...
# 1030            Transit
# 1031            Transit
# 1032            Transit
# 1033            Transit
# 1034            Transit
# Name: method, Length: 1035, dtype: object

# %%
kedi.ses
kopek.sesCikar()

# %%
df_planets.method
# Out:
# pandas.core.series.Series

# %%
df_planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df_planets.method = pd.Categorical(df_planets.method)

# %%
df_planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   category
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 42.0 KB

# %%
df_planets.shape
# Out:
# (1035, 6)

# %%
df_planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
#Veriyi betimler
df_planets.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
df_planets.describe(include="all").T
# Out:
#                count unique              top  ...      50%      75%     max
# method          1035     10  Radial Velocity  ...      NaN      NaN     NaN
# number          1035    NaN              NaN  ...        1        2       7
# orbital_period   992    NaN              NaN  ...  39.9795  526.005  730000
# mass             513    NaN              NaN  ...     1.26     3.04      25
# distance         808    NaN              NaN  ...    55.25    178.5    8500
# year            1035    NaN              NaN  ...     2010     2012    2014
#
# [6 rows x 11 columns]

# %%
df_planets.isnull()
# Out:
#       method  number  orbital_period   mass  distance   year
# 0      False   False           False  False     False  False
# 1      False   False           False  False     False  False
# 2      False   False           False  False     False  False
# 3      False   False           False  False     False  False
# 4      False   False           False  False     False  False
# ...      ...     ...             ...    ...       ...    ...
# 1030   False   False           False   True     False  False
# 1031   False   False           False   True     False  False
# 1032   False   False           False   True     False  False
# 1033   False   False           False   True     False  False
# 1034   False   False           False   True     False  False
#
# [1035 rows x 6 columns]

# %%
df_planets.isnull().values

# %%
df_planets.isnull().values.any()
# Out:
# True

# %%
df_planets.isnull().any()
# Out:
# method            False
# number            False
# orbital_period     True
# mass               True
# distance           True
# year              False
# dtype: bool

# %%
df_planets.isnull().values.sum()
# Out:
# 792

# %%
#df[orbital_period].fillna(df.orbital_period.mean(),inplace=True)

# %%
df.info()

# %%
df_planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df_planets.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
ornek_d1 = df_planets.select_dtypes(include=["int64","float64"])
ornek_d2 = df_planets.select_dtypes(exclude=["category"])

# %%
ornek_d1
# Out:
#       number  orbital_period   mass  distance  year
# 0          1      269.300000   7.10     77.40  2006
# 1          1      874.774000   2.21     56.95  2008
# 2          1      763.000000   2.60     19.84  2011
# 3          1      326.030000  19.40    110.62  2007
# 4          1      516.220000  10.50    119.47  2009
# ...      ...             ...    ...       ...   ...
# 1030       1        3.941507    NaN    172.00  2006
# 1031       1        2.615864    NaN    148.00  2007
# 1032       1        3.191524    NaN    174.00  2007
# 1033       1        4.125083    NaN    293.00  2008
# 1034       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
ornek_d2
# Out:
#       number  orbital_period   mass  distance  year
# 0          1      269.300000   7.10     77.40  2006
# 1          1      874.774000   2.21     56.95  2008
# 2          1      763.000000   2.60     19.84  2011
# 3          1      326.030000  19.40    110.62  2007
# 4          1      516.220000  10.50    119.47  2009
# ...      ...             ...    ...       ...   ...
# 1030       1        3.941507    NaN    172.00  2006
# 1031       1        2.615864    NaN    148.00  2007
# 1032       1        3.191524    NaN    174.00  2007
# 1033       1        4.125083    NaN    293.00  2008
# 1034       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
ornek_d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number          1035 non-null   int64
#  1   orbital_period  992 non-null    float64
#  2   mass            513 non-null    float64
#  3   distance        808 non-null    float64
#  4   year            1035 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 40.6 KB

# %%
ornek_d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number          1035 non-null   int64
#  1   orbital_period  992 non-null    float64
#  2   mass            513 non-null    float64
#  3   distance        808 non-null    float64
#  4   year            1035 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 40.6 KB

# %%
silinecek_df=df.select_dtypes(include=["int64","float64"])
silinecek_df2=df.select_dtypes(exclude=["category","object"])

# %%
silinecek_df.info()

# %%
silinecek_df2.info()

# %%
categorical_df=df_planets.select_dtypes(include=["category"])

# %%
categorical_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %%
categorical_df.method.unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', ...,
#                           'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#                           'Pulsation Timing Variations']

# %%
categorical_df["method"].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
categorical_df["method"].nunique()
# Out:
# 10

# %%
categorical_df.method.value_counts().plot.barh()

# %%
cont_df = df_planets.select_dtypes(exclude=["category"])

# %%
cont_df.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
cont_df.mass.mean()
# Out:
# 2.6381605847953233

# %%
cont_df.mass.count()
# Out:
# 513

# %%
cont_df.mass.median()
# Out:
# 1.26

# %%
print("Ortalama:"+str(cont_df["distance"].mean()))
print("Dolu Gözlem Sayısı:"+str(cont_df["distance"].count()))
print("Maksimum:"+str(cont_df["distance"].max()))
print("Minimumı:"+str(cont_df["distance"].min()))
print("Medyan:"+str(cont_df["distance"].median()))
print("Standart Sapma:"+str(cont_df["distance"].std()))
# Out:
# Ortalama:264.06928217821786
# Dolu Gözlem Sayısı:808
# Maksimum:8500.0
# Minimumı:1.35
# Medyan:55.25
# Standart Sapma:733.1164929404422

# %%
df_diamonds=sns.load_dataset("diamonds")
df_diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df_diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df_diamonds.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['E', 'I', 'J', 'H', 'F', 'G', 'D']

# %%
df_diamonds.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']

# %%
df_diamonds.clarity.unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']

# %%
df_diamonds.clarity.value_counts().plot.barh()

# %%
df_diamonds.columns

# %% [markdown]
# https://www.kaggle.com/shivam2503/diamonds

# %%
df_diamonds.cut.unique()

# %%
df_diamonds.cut.value_counts()

# %%
import pandas as pd

# %%
from pandas.api.types import CategoricalDtype

# %%
df_diamonds.cut = df_diamonds.cut.astype(CategoricalDtype(categories=["Fair","Good","Very Good","Premium","Ideal"],ordered=True))

# %%
df_diamonds.cut
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
o -> Fair
1 -> Good
...
5 -> Ideal

# %%
df_diamonds.cut.value_counts().plot.barh().set_title("Cut Sınıfı Veri Frekansları")
# Out:
# Text(0.5, 1.0, 'Cut Sınıfı Veri Frekansları')

# %%
df_diamonds.cut.value_counts().plot.barh().set_title("Cut'ın Sınıf Frekansları")

# %%
(df_diamonds
.cut
.value_counts()
.plot
.barh()
.set_title("Cut'ın Sınıf Frekansları"))
# Out:
# Text(0.5, 1.0, "Cut'ın Sınıf Frekansları")

# %%
sns.barplot(x="cut", y=df_diamonds.cut.index, data=df_diamonds)

# %% [markdown]
# **Çaprazlamalar**

# %%
#Kategorik değişkenleri görselleştirmek için kullanılır
#category plot
sns.catplot(x="cut", y="price", data=df_diamonds)

# %%
#Yeni bir boyut ekledik
sns.barplot(x = "color",y="price",hue="cut",data=df_diamonds)

# %%
df_diamonds.groupby(["color","cut"])["price"].mean()
# Out:
# color  cut
# D      Fair         4291.061350
#        Good         3405.382175
#        Very Good    3470.467284
#        Premium      3631.292576
#        Ideal        2629.094566
# E      Fair         3682.312500
#        Good         3423.644159
#        Very Good    3214.652083
#        Premium      3538.914420
#        Ideal        2597.550090
# F      Fair         3827.003205
#        Good         3495.750275
#        Very Good    3778.820240
#        Premium      4324.890176
#        Ideal        3374.939362
# G      Fair         4239.254777
#        Good         4123.482204
#        Very Good    3872.753806
#        Premium      4500.742134
#        Ideal        3720.706388
# H      Fair         5135.683168
#        Good         4276.254986
#        Very Good    4535.390351
#        Premium      5216.706780
#        Ideal        3889.334831
# I      Fair         4685.445714
#        Good         5078.532567
#        Very Good    5255.879568
#        Premium      5946.180672
# ...

# %%
sns.distplot(df_diamonds.price,kde=True) #kernel distribution
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Histogram: Sürekli değişkeni belli aralıklara bölerek o arallıklarldaki frekansı yansıtır

# %%
#y ekseninde ölçekler birbirinden farklı olacağından dolayı ölçeklendirilmiştir.
sns.distplot(df_diamonds.price)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#sadece yopunluk grafiğini görmek için
sns.distplot(df_diamonds.price,hist=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_diamonds.price,kde=False)

# %%
sns.distplot(df_diamonds.price,bins=100,kde=True,hist=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_diamonds.price,bins=200,kde=True,hist=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df_diamonds.price,shade=True)

# %% [markdown]
# Buradaki alanı oluşturan kategorik verilerin incelenmesi.

# %%
(sns
 .FacetGrid(df_diamonds,
            hue="cut",
            height=5,
            xlim = (0, 15000))
 .map(sns.kdeplot,"price",shade=True)
 .add_legend())

# %%
(sns
 .FacetGrid(df_diamonds,
            hue="color",
            height=5,
            xlim = (0, 10000))
 .map(sns.kdeplot, "price", shade=True)
 .add_legend())

# %%
sns.catplot(x="cut", y="price", hue="color", kind="point", data = df_diamonds)

# %%
df_diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df_diamonds.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['J' < 'I' < 'H' < 'G' < 'F' < 'E' < 'D']

# %%
df_diamonds.color = df_diamonds.color.astype(CategoricalDtype(categories = ["J","I","H","G","F","E","D"],ordered=True))

# %%
df_tips = sns.load_dataset("tips")

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips.shape
# Out:
# (244, 7)

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df_tips.isnull().any()
# Out:
# total_bill    False
# tip           False
# sex           False
# smoker        False
# day           False
# time          False
# size          False
# dtype: bool

# %%
df_tips.isnull().values.any()
# Out:
# False

# %%
df_tips.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
#df_tips.size = df_tips.size.astype(CategoricalDtype(categories = ["1","2","3","4","5","6"],ordered=False))

# %%
df_tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
df_tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
df_tips.sex.unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']

# %%
df_tips.smoker.unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %% [markdown]
# https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset

# %%
df_tips.total_bill.describe().T
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
sns.kdeplot(x=df_tips.total_bill)

# %%
sns.boxplot(x=df_tips.total_bill)

# %%
sns.boxplot(y=df_tips.total_bill, orient="v") #vertical

# %%
df_tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
df_tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.boxplot(x="day", y="total_bill", data=df_tips)

# %%
sns.boxplot(x="time",y="total_bill",data=df_tips)

# %%
sns.boxplot(x="size",y="total_bill",data=df_tips)

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=df_tips)

# %%
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(x="size", y="tip", hue="sex", data=df_tips)

# %% [markdown]
# KORELASYON

# %%
sns.scatterplot(x="total_bill", y="tip", data=df_tips)

# %%
sns.scatterplot(x="tip", y="total_bill", data=df_tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex",data=df_tips)

# %%
sns.scatterplot(x="tip",y="total_bill",hue="day",style="time",size="size",data=df_tips)

# %%
sns.scatterplot(x="tip",y="total_bill",style="time",data = df_tips)

# %% [markdown]
# Doğrusal İlişkinin Doğruyla Gösterilmesi

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill", y="tip", data= df_tips)

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",data=df_tips)

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",data=df_tips)

# %%
df_tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",row="sex",data=df_tips)

# %%
sns.pairplot(df_tips)

# %%
df_iris = sns.load_dataset("iris")

# %% [markdown]
# https://www.kaggle.com/uciml/iris

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df_iris)

# %%
sns.distplot(df_iris.petal_width,hist=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df_iris, hue="species")

# %%
sns.pairplot(df_iris, hue="species" ,markers=["o","s","D"])

# %% [markdown]
# https://python-graph-gallery.com/41-control-marker-features/

# %%
sns.pairplot(df_iris, kind="reg", hue="species")

# %% [markdown]
# ISI HARİTASI

# %%
df_flights_new = sns.load_dataset("flights")

# %%
df_flights_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df_flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_flights_new.year.astype("category")
# Out:
# 0      1949
# 1      1949
# 2      1949
# 3      1949
# 4      1949
#        ...
# 139    1960
# 140    1960
# 141    1960
# 142    1960
# 143    1960
# Name: year, Length: 144, dtype: category
# Categories (12, int64): [1949, 1950, 1951, 1952, ..., 1957, 1958, 1959, 1960]

# %%
df_flights.shape
# Out:
# (144, 3)

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 12 entries, Jan to Dec
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1949    12 non-null     int64
#  1   1950    12 non-null     int64
#  2   1951    12 non-null     int64
#  3   1952    12 non-null     int64
#  4   1953    12 non-null     int64
#  5   1954    12 non-null     int64
#  6   1955    12 non-null     int64
#  7   1956    12 non-null     int64
#  8   1957    12 non-null     int64
#  9   1958    12 non-null     int64
#  10  1959    12 non-null     int64
#  11  1960    12 non-null     int64
# dtypes: int64(12)
# memory usage: 1.5 KB

# %%
df_flights=df_flights.pivot("month","year","passengers")

# %%
df_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df_flights)

# %%
sns.heatmap(df_flights, annot=True)

# %%
sns.heatmap(df_flights,annot=True,fmt="d")

# %%
sns.heatmap(df_flights,annot=True, fmt="d", linewidths=.5)
